# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeClassifier
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

from lab_tools import CIFAR10, get_hog_image

dataset = CIFAR10('../../extern_data/CIFAR10/')
X_train, y_train = dataset.train['hog'][:15000], dataset.train['labels'][:15000]
X_test, y_test = dataset.test['hog'], dataset.test['labels']
# Out:
# Pre-loading training data
# Pre-loading test data

# %% [markdown]
# # Ridge Classifier

# %% [markdown]
# ## Training & Tuning

# %%
tuned_parameters = [{"alpha": np.arange(0, 1, 0.2)}]

clf = GridSearchCV(RidgeClassifier(), tuned_parameters, cv=2)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_, clf.best_score_)

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'alpha': 0.2} 0.7156666666666667
# 0.690 (+/-0.027) for {'alpha': 0.0}
# 0.716 (+/-0.007) for {'alpha': 0.2}
# 0.704 (+/-0.003) for {'alpha': 0.4}
# 0.699 (+/-0.005) for {'alpha': 0.6000000000000001}
# 0.695 (+/-0.003) for {'alpha': 0.8}

# %% [markdown]
# ## Test

# %%
clf = RidgeClassifier(alpha = 0.2)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, pred)
print(f"Accuracy: {accuracy:.3f}")

cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Accuracy: 0.720
# [[744 186  70]
#  [133 659 208]
#  [ 72 172 756]]

# %% [markdown]
# # Nearest Neighbor
#
# ## Training & Tuning

# %%
# NORMALIZATION
X_train_NN = preprocessing.normalize(X_train, axis=0)
X_test_NN = preprocessing.normalize(X_test, axis=0)

tuned_parameters = {"n_neighbors": np.arange(1, 30, 2), "weights": ["distance", "uniform"], "p": [1]}

clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, cv=2)

#clf = KNeighborsClassifier(n_neighbors=10, weights='distance', p = 1)
clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_)
print()

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
#
# 0.673 (+/-0.015) for {'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.673 (+/-0.015) for {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.692 (+/-0.011) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.696 (+/-0.003) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.705 (+/-0.003) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.719 (+/-0.008) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.718 (+/-0.000) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.722 (+/-0.009) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.716 (+/-0.011) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.720 (+/-0.007) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.715 (+/-0.016) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.719 (+/-0.017) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.713 (+/-0.009) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.714 (+/-0.007) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.713 (+/-0.019) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.713 (+/-0.007) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.711 (+/-0.023) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.710 (+/-0.021) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.711 (+/-0.008) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.709 (+/-0.008) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.708 (+/-0.006) for {'n_neighbors': 21, 'p': 1, 'weights': 'distance'}
# 0.708 (+/-0.005) for {'n_neighbors': 21, 'p': 1, 'weights': 'uniform'}
# 0.712 (+/-0.010) for {'n_neighbors': 23, 'p': 1, 'weights': 'distance'}
# 0.711 (+/-0.005) for {'n_neighbors': 23, 'p': 1, 'weights': 'uniform'}
# 0.714 (+/-0.003) for {'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# 0.713 (+/-0.003) for {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'}
# 0.714 (+/-0.005) for {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# 0.715 (+/-0.005) for {'n_neighbors': 27, 'p': 1, 'weights': 'uniform'}
# 0.713 (+/-0.011) for {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.715 (+/-0.009) for {'n_neighbors': 29, 'p': 1, 'weights': 'uniform'}

# %% [markdown]
# ## Test

# %%
clf = KNeighborsClassifier(n_neighbors=7, weights='uniform', p = 1)

X_train_NN = preprocessing.normalize(X_train, axis=0)
X_test_NN = preprocessing.normalize(X_test, axis=0)

clf.fit(X_train_NN, y_train)

pred = clf.predict(X_test_NN)

accuracy = accuracy_score(y_test, pred)
print(f"Accuracy: {accuracy:.3f}")

cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Accuracy: 0.761
# [[751 188  61]
#  [ 98 763 139]
#  [ 36 195 769]]

# %% [markdown]
# # Decision Trees
#
# ## Training & Tuning

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

tuned_parameters = [{'criterion': ['gini', 'entropy', 'log_loss'], 
                     "random_state": [0, 1, 5], 
                     'max_depth': [1, 5, 10, 15, 20],
                     'splitter': ["best", "random"],
                     'ccp_alpha': [0, 0.1, 0.5, 1, 10]
                    }]

clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, cv=2)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_)

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.426 (+/-0.013) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.425 (+/-0.040) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.426 (+/-0.013) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.413 (+/-0.001) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.426 (+/-0.013) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.448 (+/-0.006) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.536 (+/-0.036) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.541 (+/-0.009) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.538 (+/-0.037) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.542 (+/-0.011) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.538 (+/-0.040) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.532 (+/-0.021) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.546 (+/-0.021) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.546 (+/-0.007) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.541 (+/-0.023) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.529 (+/-0.002) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.540 (+/-0.023) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.546 (+/-0.007) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.540 (+/-0.017) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.517 (+/-0.014) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.541 (+/-0.025) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.524 (+/-0.018) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.544 (+/-0.031) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.538 (+/-0.012) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.537 (+/-0.024) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.527 (+/-0.009) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.541 (+/-0.024) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.539 (+/-0.017) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.546 (+/-0.027) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.531 (+/-0.035) for {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.426 (+/-0.011) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.425 (+/-0.040) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.426 (+/-0.011) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.413 (+/-0.001) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.426 (+/-0.011) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.448 (+/-0.006) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.542 (+/-0.000) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.527 (+/-0.028) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.543 (+/-0.001) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.507 (+/-0.015) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.543 (+/-0.000) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.505 (+/-0.007) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.539 (+/-0.008) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.533 (+/-0.010) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.542 (+/-0.001) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.523 (+/-0.028) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.538 (+/-0.001) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.531 (+/-0.016) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.523 (+/-0.021) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.532 (+/-0.014) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.533 (+/-0.006) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.533 (+/-0.004) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.530 (+/-0.018) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.525 (+/-0.009) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.523 (+/-0.021) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.520 (+/-0.006) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.533 (+/-0.006) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.537 (+/-0.016) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.530 (+/-0.018) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.526 (+/-0.028) for {'ccp_alpha': 0, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.385 (+/-0.093) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 0.5, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 0.5, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 1, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 1, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'gini', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# 0.339 (+/-0.000) for {'ccp_alpha': 10, 'criterion': 'entropy', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 1, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 5, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 10, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 15, 'random_state': 5, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 0, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 1, 'splitter': 'random'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'best'}
# nan (+/-nan) for {'ccp_alpha': 10, 'criterion': 'log_loss', 'max_depth': 20, 'random_state': 5, 'splitter': 'random'}

# %% [markdown]
# ## Test

# %%
clf = DecisionTreeClassifier(random_state=5)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

score = accuracy_score(y_test, pred)
print(f"Normal Nearest Neighbor: {score:.3f}")
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Normal Nearest Neighbor: 0.531
# [[562 260 178]
#  [207 525 268]
#  [185 310 505]]

# %% [markdown]
# # Random Forest
#
# ## Training & Tuning

# %%
from sklearn.ensemble import RandomForestClassifier

tuned_parameters = [{
                     'n_estimators': [10, 100, 200],
                     'criterion': ['gini', 'entropy'], 
                     "random_state": [0, 1, 5], 
                     'max_depth': [1, 5, 10, 15, 20]
                    }]

clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=2)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_, clf.best_score_)

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200, 'random_state': 1} 0.7350000000000001
# 0.526 (+/-0.013) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 10, 'random_state': 0}
# 0.523 (+/-0.015) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 10, 'random_state': 1}
# 0.497 (+/-0.034) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 10, 'random_state': 5}
# 0.555 (+/-0.023) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 100, 'random_state': 0}
# 0.567 (+/-0.025) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 100, 'random_state': 1}
# 0.560 (+/-0.033) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 100, 'random_state': 5}
# 0.570 (+/-0.032) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 200, 'random_state': 0}
# 0.564 (+/-0.037) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 200, 'random_state': 1}
# 0.579 (+/-0.043) for {'criterion': 'gini', 'max_depth': 1, 'n_estimators': 200, 'random_state': 5}
# 0.627 (+/-0.012) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 10, 'random_state': 0}
# 0.658 (+/-0.003) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 10, 'random_state': 1}
# 0.634 (+/-0.007) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 10, 'random_state': 5}
# 0.699 (+/-0.013) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 100, 'random_state': 0}
# 0.696 (+/-0.014) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 100, 'random_state': 1}
# 0.700 (+/-0.025) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 100, 'random_state': 5}
# 0.701 (+/-0.017) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 200, 'random_state': 0}
# 0.710 (+/-0.027) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 200, 'random_state': 1}
# 0.701 (+/-0.026) for {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 200, 'random_state': 5}
# 0.639 (+/-0.007) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 10, 'random_state': 0}
# 0.627 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 10, 'random_state': 1}
# 0.626 (+/-0.003) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 10, 'random_state': 5}
# 0.721 (+/-0.009) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100, 'random_state': 0}
# 0.722 (+/-0.015) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100, 'random_state': 1}
# 0.709 (+/-0.026) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100, 'random_state': 5}
# 0.734 (+/-0.007) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 200, 'random_state': 0}
# 0.728 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 200, 'random_state': 1}
# 0.723 (+/-0.007) for {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 200, 'random_state': 5}
# 0.624 (+/-0.032) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 10, 'random_state': 0}
# 0.635 (+/-0.008) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 10, 'random_state': 1}
# 0.623 (+/-0.021) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 10, 'random_state': 5}
# 0.713 (+/-0.011) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 100, 'random_state': 0}
# 0.720 (+/-0.019) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 100, 'random_state': 1}
# 0.725 (+/-0.005) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 100, 'random_state': 5}
# 0.724 (+/-0.011) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 200, 'random_state': 0}
# 0.727 (+/-0.014) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 200, 'random_state': 1}
# 0.727 (+/-0.008) for {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 200, 'random_state': 5}
# 0.630 (+/-0.039) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 10, 'random_state': 0}
# 0.636 (+/-0.005) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 10, 'random_state': 1}
# 0.627 (+/-0.001) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 10, 'random_state': 5}
# 0.722 (+/-0.011) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 100, 'random_state': 0}
# 0.719 (+/-0.007) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 100, 'random_state': 1}
# 0.722 (+/-0.003) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 100, 'random_state': 5}
# 0.729 (+/-0.011) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 200, 'random_state': 0}
# 0.730 (+/-0.002) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 200, 'random_state': 1}
# 0.726 (+/-0.009) for {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 200, 'random_state': 5}
# 0.523 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 10, 'random_state': 0}
# 0.526 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 10, 'random_state': 1}
# 0.519 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 10, 'random_state': 5}
# 0.557 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 100, 'random_state': 0}
# 0.569 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 100, 'random_state': 1}
# 0.567 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 100, 'random_state': 5}
# 0.572 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 200, 'random_state': 0}
# 0.574 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 200, 'random_state': 1}
# 0.582 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 1, 'n_estimators': 200, 'random_state': 5}
# 0.626 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 10, 'random_state': 0}
# 0.631 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 10, 'random_state': 1}
# 0.630 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 10, 'random_state': 5}
# 0.707 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 100, 'random_state': 0}
# 0.700 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 100, 'random_state': 1}
# 0.689 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 100, 'random_state': 5}
# 0.703 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 200, 'random_state': 0}
# 0.703 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 200, 'random_state': 1}
# 0.701 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 200, 'random_state': 5}
# 0.633 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 10, 'random_state': 0}
# 0.631 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 10, 'random_state': 1}
# 0.640 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 10, 'random_state': 5}
# 0.716 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100, 'random_state': 0}
# 0.715 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100, 'random_state': 1}
# 0.720 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100, 'random_state': 5}
# 0.724 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 200, 'random_state': 0}
# 0.722 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 200, 'random_state': 1}
# 0.725 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 200, 'random_state': 5}
# 0.619 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 10, 'random_state': 0}
# 0.624 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 10, 'random_state': 1}
# 0.622 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 10, 'random_state': 5}
# 0.713 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 100, 'random_state': 0}
# 0.720 (+/-0.007) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 100, 'random_state': 1}
# 0.713 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 100, 'random_state': 5}
# 0.727 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 200, 'random_state': 0}
# 0.733 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 200, 'random_state': 1}
# 0.719 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 200, 'random_state': 5}
# 0.621 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 10, 'random_state': 0}
# 0.623 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 10, 'random_state': 1}
# 0.621 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 10, 'random_state': 5}
# 0.718 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 100, 'random_state': 0}
# 0.718 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 100, 'random_state': 1}
# 0.721 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 100, 'random_state': 5}
# 0.725 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200, 'random_state': 0}
# 0.735 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200, 'random_state': 1}
# 0.722 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200, 'random_state': 5}

# %% [markdown]
# ## Test

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(criterion= 'entropy', max_depth= 20, n_estimators= 200, random_state= 1)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

score = accuracy_score(y_test, pred)
print(f"Normal Nearest Neighbor: {score:.3f}")
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Normal Nearest Neighbor: 0.775
# [[797 149  54]
#  [121 743 136]
#  [ 55 161 784]]

# %% [markdown]
# # Neural Network
#
# ## Training & Tuning

# %%
from sklearn.neural_network import MLPClassifier

tuned_parameters = [{
                    "random_state": [10], # 0, 5, ,
                    "alpha": [0.0001], # , 0.0005, 0.00005,
                    "hidden_layer_sizes": [1, 10, 50, 100, 200, 300, 500, 1000], #[100, 200, 300], 
                    "activation":["relu"], # ["identity", "tanh", "relu"],
                    "solver":["adam"], # ["lbfgs", "adam"],
                    "learning_rate_init": [0.001]
                    }]

clf = GridSearchCV(MLPClassifier(), tuned_parameters, cv=2)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")

print(clf.best_params_, clf.best_score_)

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 1000, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'} 0.7916000000000001
# 0.333 (+/-0.000) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 1, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.753 (+/-0.011) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 10, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.757 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 50, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.766 (+/-0.000) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.779 (+/-0.000) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 200, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.782 (+/-0.007) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 300, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.788 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 500, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}
# 0.792 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 1000, 'learning_rate_init': 0.001, 'random_state': 10, 'solver': 'adam'}

# %% [markdown]
# ## Test

# %%
clf = MLPClassifier(random_state=1, hidden_layer_sizes= 50)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

score = accuracy_score(y_test, pred)
print(f"Normal Nearest Neighbor: {score:.3f}")
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Normal Nearest Neighbor: 0.792
# [[826 134  40]
#  [127 724 149]
#  [ 38 135 827]]

# %% [markdown]
# # SVM
#
# ## Training & Tuning

# %%
from sklearn.svm import SVC

tuned_parameters = [{
                     "gamma": ['scale'],
                     "C": [ 3],
                     "kernel": ["poly", "rbf"],
                     "degree": [1, 2, 3, 4, 5, 10]
                    }]

clf = GridSearchCV(SVC(), tuned_parameters, cv=2)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_, clf.best_score_)

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]
for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
# {'C': 3, 'degree': 1, 'gamma': 'scale', 'kernel': 'rbf'} 0.766
# 0.718 (+/-0.012) for {'C': 3, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.750 (+/-0.015) for {'C': 3, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.750 (+/-0.009) for {'C': 3, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.746 (+/-0.001) for {'C': 3, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.733 (+/-0.005) for {'C': 3, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.610 (+/-0.085) for {'C': 3, 'degree': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 0.766 (+/-0.003) for {'C': 3, 'degree': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ## Test

# %%
#clf = MLPClassifier(random_state=5, activation="relu", hidden_layer_sizes=27, solver="adam")
clf = MLPClassifier(random_state=10, hidden_layer_sizes=1000, activation="relu", alpha=0.0001)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

score = accuracy_score(y_test, pred)
print(f"Normal Nearest Neighbor: {score:.3f}")
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# Normal Nearest Neighbor: 0.826
# [[859 106  35]
#  [121 776 103]
#  [ 35 122 843]]
